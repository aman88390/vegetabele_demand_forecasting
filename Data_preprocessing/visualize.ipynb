# %%
# Install seaborn
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Necessary Imports 
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import eda  # this imports Data_preprocessing/eda.py, since notebook is in same folder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Data Loading and data information
fruit_df = eda.load_data("fruit_sales_clean.csv")
veg_df = eda.load_data("vegetable_sales_clean.csv")
# Out:
# 📂 Loading: fruit_sales_clean.csv
#         date    item  quantity_sold  price is_event_raw is_weekend_raw  \
# 0 2025-08-03   Apple             21    142           No            Yes
# 1 2025-08-03  Banana             70     38           No            Yes
# 2 2025-08-03   Mango             14     97           No            Yes
# 3 2025-08-03  Orange             29     58           No            Yes
# 4 2025-08-04   Apple             21    138           No             No
#
#   weather_raw  is_event  day_of_week  is_weekend weather  month season
# 0       Sunny         0            6           1   Sunny      8  Rainy
# 1       Sunny         0            6           1   Sunny      8  Rainy
# 2         NaN         0            6           1   Sunny      8  Rainy
# 3       Sunny         0            6           1   Sunny      8  Rainy
# 4       Sunny         0            0           0   Sunny      8  Rainy
#
# 📂 Loading: vegetable_sales_clean.csv
# ...

# %%
#Basic Exploratory Data Analysis
eda.eda_basic(fruit_df, title="Fruit Data")
eda.eda_basic(veg_df, title="Vegetable Data")
# Out:
# ========== 📊 BASIC EDA: Fruit Data ==========
#
# 🔹 Shape: (589, 13)
#
# 🔍 Missing values:
# date               0
# item               0
# quantity_sold      0
# price              0
# is_event_raw       0
# is_weekend_raw     0
# weather_raw       21
# is_event           0
# day_of_week        0
# is_weekend         0
# weather            0
# month              0
# season             0
# dtype: int64
#
# 🧺 Items:
# item
# Banana    119
# Apple     118
# Grapes    118
# Mango     117
# Orange    117
# Name: count, dtype: int64
#
# 🌦 Weather distribution:
# weather
# Sunny     423
# Cloudy    132
# Rain       34
# Name: count, dtype: int64
#
# 📅 Season distribution:
# season
# Rainy         290
# Transition    150
# Winter        149
# Name: count, dtype: int64
#
# ========== 📊 BASIC EDA: Vegetable Data ==========
#
# 🔹 Shape: (1161, 13)
#
# 🔍 Missing values:
# date               0
# item               0
# quantity_sold      0
# price              0
# is_event_raw       0
# ...

# %%
#Fruits Trend Plots
eda.plot_trends(fruit_df, title_prefix="Fruits")

# %%
# Fruits Item-wise EDA
eda.item_wise_eda(fruit_df, title_prefix="Fruits")

# %%
#Vegetables Trend Plots
eda.plot_trends(veg_df, title_prefix="Vegetables")

# %%
# Vegetables Item-wise EDA
eda.item_wise_eda(veg_df, title_prefix="Vegetables")

# %%
#Fruits Correlation Heatmap
eda.plot_correlation_heatmap(fruit_df, "Fruits")
eda.plot_correlation_heatmap(veg_df, "Vegetables")

# %%
#Fruits Item-to-item demand correlation
eda.plot_item_correlation(fruit_df, "Fruits")
eda.plot_item_correlation(veg_df, "Vegetables")
